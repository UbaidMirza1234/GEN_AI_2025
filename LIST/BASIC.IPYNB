# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# LIST

# %%
#colleletion of items
#LIST IS MUTABLE (CHANGEABLE)
#LIST IS ORDERED
# LIST IS INDEXED
# IT IS ALLOW DUPLICATES VALUES
#LIST IS HETEROGENEOUS

# %%
lst=[1,2,"hello", 3, 4.5, "world", 1.2,True]
print(lst)
print(type(lst))
# Out:
# [1, 2, 'hello', 3, 4.5, 'world', 1.2, True]
# <class 'list'>

# %% [markdown]
# string/sliccing

# %%
print(lst[0])  # Accessing the first element
# Out:
# 1

# %%
print(lst[-1])
# Out:
# True

# %%
print(lst[1:4])
# Out:
# [2, 'hello', 3]

# %%
lst.index("hello")  # Finding the index of "hello"
# Out:
# 2

# %%
lst.append("new item")  # Adding an item to the end of the list
print(lst)
# Out:
# [1, 2, 'hello', 3, 4.5, 'world', 1.2, True, 'new item']

# %%
#ormatted string 
age=10
text="my age is "+ str(age)
print(text)
# Out:
# my age is 10

# %%
#with f-string#
age=10
text=f"my age is {age}"
print(text)
# Out:
# my age is 10

# %% [markdown]
# TYPE CASTING

# %%
#TYPE  CASTING --DATATYPE CONVERSION
a=10
b=float(a)
print(b)  # Output: 10.0
# Out:
# 10.0

# %% [markdown]
# lenght len()

# %%
#lenght --len() ---number of items in a list
print(len(lst))  # Output: 8
# Out:
# 9

# %% [markdown]
# updating value

# %%
lst=["apple", "banana", "cherry"]
lst[1] = "orange"  # Changing the second item
print(lst)
# Out:
# ['apple', 'orange', 'cherry']

# %% [markdown]
# Slicing

# %%
lst=["apple", "banana", "cherry", "orange", "kiwi"]
lst[0:2] = ["grape", "melon"]  # Replacing the first two items
print(lst)
# Out:
# ['grape', 'melon', 'cherry', 'orange', 'kiwi']

# %%
lst=["apple", "banana", "cherry", "orange", "kiwi"]
lst[0:1] = ["grape", "melon"]  # Replacing the first two items
print(lst) 
#no of item w eare accessing are less and no of item
# we are replacing are more
# Out:
# ['grape', 'melon', 'banana', 'cherry', 'orange', 'kiwi']

# %% [markdown]
# METHOD OF SLICING

# %%
lst=["apple", "banana", "cherry"]
lst
# Out:
# ['apple', 'banana', 'cherry']

# %%
lst=lst.index("banana")  # Finding the index of "banana"
print(lst)  # Output: 1
# Out:
# 1

# %%
lst = ["apple", "banana", "cherry"]  # Re-initialize lst as a list
lst.append("new item")  # Adding an item to the end of the list
print(lst)  # Output: ['apple', 'banana', 'cherry', 'new item']
# Out:
# ['apple', 'banana', 'cherry', 'new item']

# %%
lst=["red","black","blue","white","orange"]
#lst.sort(reverse=True)        #ascending

#lst.reverse()

#lst.append("red")

#lst.append("red")             #value insert

#lst.extend(["red","black"])

#lst.insert(2,"red")

#lst.remove("red")              #remove

#lst.pop(0)

print(lst)
# Out:
# ['black', 'blue', 'white', 'orange']

# %% [markdown]
# TUPLE
