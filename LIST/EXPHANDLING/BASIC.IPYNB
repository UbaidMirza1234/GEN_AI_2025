# %%
#EXCEPTION HANDLIN------ERROR HANDLING-----ERROR HANDLING IN PYTHON
#4 TYPE OF BLOCK

#try

#CODE THAT MIGHT CAUSE AN ERROR

#EXCET

#CODE TO HANDLE THE ERROR

#ELSE

#CODE TO EXECUTE THE ERROR

#FINALLY
#CODE TO EXECUTE REGARDLESS OF ERROR

# %%
try:
    print(10/0)
except:
    print("error")
else:
    print("no error")
finally:
    print("finally")
# Out:
# error
# finally

# %%
try:
    print(10/10)
except:
    print("error")
else:
    print("no error")
finally:
    print("finally")
# Out:
# 1.0
# no error
# finally

# %%
try:
    print(10/10)
except  Exception as e: # alias(nickname)
    print("error","-------",e)
else:
    print("no error")
finally:
    print("finally")
# Out:
# 1.0
# no error
# finally

# %%
try:
    l=[1,2,3]
    print[[3]]
    
except  Exception as e: # alias(nickname)
    print("error","-------",e)
else:
    print("no error")
finally:
    print("finally")
# Out:
# error ------- 'builtin_function_or_method' object is not subscriptable
# finally

# %%
try:
    l=[1,2,3]
    print[l[3]]
    
except  IndexError as e: # alias(nickname)
    print("error","-------",e)
else:
    print("no error")
finally:
    print("finally")
# Out:
# error ------- list index out of range
# finally
