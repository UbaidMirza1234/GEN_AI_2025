# %% [markdown]
# IF -ELSE

# %%
#IF ELSE --- CONDITION STAETEMENT --- DECISION  CONDITION CHECK

# %% [markdown]
# IF- ELSE-ELIF

# %%
a=10
b=20
if b>a :
    #indentation
    print("b is greter than a")
# Out:
# b is greter than a

# %%
a=70
b=34
if b>a :
    #indentation
    print("b is greater than a")
else:
    print("a is greater trhan b")    
    pass
# Out:
# a is greter trhan b

# %%
a=10
b=10
if b>a :
    #indentation
    print("b is greater than a")
elif a==b:    
    print("a is equal to b")
else:
    print("a is greater trhan b")    
    pass
# Out:
# a is equal to b
