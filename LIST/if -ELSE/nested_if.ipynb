# %%
a=10
b=10
c=30

if a>b :
    print("a is greater than b")
    if a>c:
        print("a is greter than c")
else:
    print("a is less than b")
    if b>c:
        print("b is greter tghan c")
    else:
        print("b is less than c")
# Out:
# a is less than b
# b is less than c

# %% [markdown]
# user  input

# %%
a=input("enter a number")
print(a)
print(type(a))
# Out:
# 1
# <class 'str'>

# %% [markdown]
# posituvce or  negative

# %%
a = int(input("enter the number"))
if a > 0:
    print("no is positive")
else:
    print("no is negative")
# Out:
# no is positive

# %% [markdown]
# check if a number is divesible by 5 and 11

# %%
a = int(input("enter the number "))
if (a % 5 == 0) and (a % 11 == 0):
	print("Number is divisible by both 5 and 11")
else:
	print("Number is not divisible by both 5 and 11")
# Out:
# Number is not divisible by both 5 and 11

# %% [markdown]
# vovel or  constant
