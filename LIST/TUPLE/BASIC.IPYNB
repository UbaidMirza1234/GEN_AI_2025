# %% [markdown]
# TUPLE

# %%
#TPL IS IMMUTABLE ,ORDERD,INDEXED,
#HETEROGENOUS,ALLOW DUPLICACY

# %%
tpl=("hello",1,2,True,"hello",22,33)
print(tpl)
print(type(tpl))
# Out:
# ('hello', 1, 2, True, 'hello', 22, 33)
# <class 'tuple'>

# %% [markdown]
# single element tuple

# %%
tpl=("upflair",)
print(tpl)
print(type(tpl))
# Out:
# ('upflair',)
# <class 'tuple'>

# %%
tpl = ("upflair",)
tpl
tpl.index("upflair")
# Out:
# 0
