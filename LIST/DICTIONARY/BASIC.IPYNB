# %% [markdown]
# DICTIONARY

# %% [markdown]
# ORDER,
# MUTABLE,
# INDEXED,
# ALLOWS DUPLICATE VALUE,
# KEY VALUE Pair

# %%
dt={
    "name":"upflair",
     "course":"data science",
     "duration":45}

print(dt)
# Out:
# {'name': 'upflair', 'course': 'data science', 'duration': 45}

# %%
dt["name"]
# Out:
# 'upflair'

# %%
dt["name"]="Full name"
dt
# Out:
# {'name': 'Full name', 'course': 'data science', 'duration': 45}

# %% [markdown]
# METHOD

# %%
dt.get("name")
# Out:
# 'Full name'

# %%
dt.items()
# Out:
# dict_items([('name', 'Full name'), ('course', 'data science'), ('duration', 45)])

# %%
dt.keys()
# Out:
# dict_keys(['name', 'course', 'duration'])

# %%
dt.values()
# Out:
# dict_values(['Full name', 'data science', 45])

# %%
dt.pop("name")
# Out:
# 'Full name'

# %%
dt.popitem()
# Out:
# ('duration', 45)

# %%
dt.update({"name":"google","age":10})
dt
# Out:
# {'course': 'data science', 'name': 'google', 'age': 10}
